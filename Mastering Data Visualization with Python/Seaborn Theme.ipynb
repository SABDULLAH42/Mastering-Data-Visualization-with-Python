# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data
import seaborn as sns

# %%
housing_df = data('Housing')

# %%
sns.set_theme(style='dark', context='talk', palette='icefire')
sns.catplot(data = housing_df, x='bedrooms', y='price', kind='box');

# %%
np.random.normal()
# Out:
# 32

# %%
np.random.seed(45)

# %%
import random 
for i in range(5):
    random.seed(0)
    print(random.randint(1, 1000))
# Out:
# 865
# 865
# 865
# 865
# 865

# %%
import random

random.seed(3)
print(random.randint(1, 1000))
# Out:
# 244
